# %% [markdown]
# # Comparison of Forecasting Models Using RMSE value

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## 1. AMAZON

# %%
Models=['ARIMA','PROPHET','KERAS with LSTM']
RMSE=[85.78,128.95,74.9]
graph = np.arange(len(Models))
plt.style.use('fivethirtyeight')
plt.figure(figsize=(10,6))
plt.bar(graph,RMSE, label="RMSE")
plt.xticks(graph,Models)
plt.ylabel("Value of RMSE")
plt.title('Comparison Report Graph - AMAZON STOCK PRICES')
plt.legend()

# %%
Models=['ARIMA','PROPHET','KERAS with LSTM']
RMSE=[3.6,6.44,2.4]
graph = np.arange(len(Models))
plt.style.use('fivethirtyeight')
plt.figure(figsize=(10,6))
plt.bar(graph,RMSE, label="RMSE")
plt.xticks(graph,Models)
plt.ylabel("Value of RMSE")
plt.title('Comparison Report Graph - APPLE STOCK PRICES')
plt.legend()

# %%
Models=['ARIMA','PROPHET','KERAS with LSTM']
RMSE=[52.75,59.48,29.72]
graph = np.arange(len(Models))
plt.style.use('fivethirtyeight')
plt.figure(figsize=(10,6))
plt.bar(graph,RMSE, label="RMSE")
plt.xticks(graph,Models)
plt.ylabel("Value of RMSE")
plt.title('Comparison Report Graph - GOOGLE STOCK PRICES')
plt.legend()
